# %%
import pandas as pd
import numpy as np

# %%
# Load file
schools_complete = "schools_complete.csv"
students_complete = "students_complete.csv"

# %%
# Read School and Student Data File and store into Pandas DataFrames
schools_data = pd.read_csv(schools_complete)
students_data = pd.read_csv(students_complete)

# %%
# Combine the data into a single dataset.  
schools_complete = pd.merge(students_data, schools_data, how="left", on=["school_name", "school_name"])

# %%
schools_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#Total schools
total_schools = schools_complete["school_name"].nunique()
total_schools
# Out:
# 15

# %%
#Total students
total_students = schools_complete["student_name"].count()
total_students
# Out:
# 39170

# %%
#Total budget
total_budget = pd.unique(schools_complete['budget'].values)
budget_final = total_budget.sum()
budget_final
# Out:
# 24649428

# %%
#Average math score
avr_math_score = schools_complete['math_score'].mean()
avr_math = round (avr_math_score , 2)
avr_math
# Out:
# 78.99

# %%
#Average reading score
avr_reading_score = schools_complete['reading_score'].mean()
avr_reading = round (avr_reading_score , 2)
avr_reading
# Out:
# 81.88

# %%
#% passing math (the percentage of students who passed math)
pass_maths = schools_complete['math_score']>=70
final_maths = schools_complete[pass_maths]
final_maths['math_score'].count()
final_no_maths = final_maths['math_score'].count()
per_pass_maths = final_no_maths / total_students * 100 
round_maths = round (per_pass_maths , 2)
round_maths
# Out:
# 74.98

# %%
#% passing reading (the percentage of students who passed reading)
pass_reading = schools_complete['reading_score']>=70
final_reading = schools_complete[pass_reading]
final_reading['reading_score'].count()
final_no_reading = final_reading['reading_score'].count()
per_pass_reading = final_no_reading / total_students * 100
round_reading = round (per_pass_reading , 2)
round_reading
# Out:
# 85.81

# %%
#% overall passing (the percentage of students who passed math AND reading)
pass_overall = schools_complete[(schools_complete['math_score']>=70) & (schools_complete['reading_score']>=70)] 
total_overall = pass_overall['reading_score'].count()
per_pass_overall = total_overall / total_students * 100
round_overall = round(per_pass_overall, 2)
round_overall
# Out:
# 65.17

# %%
#High-level snapshot
results_list = [[total_schools,total_students,budget_final,avr_math,avr_reading,round_maths,round_reading,round_overall]]

df = pd.DataFrame(results_list, index=['District Summary'], columns=['Total number of schools','Total number of students','Total budget','Average math score','Average reading score','Passing math score (%)','Passing reading score (%)', 'Passing math & reading score (%)'])
df.head()
# Out:
#                   Total number of schools  Total number of students  \
# District Summary                       15                     39170
#
#                   Total budget  Average math score  Average reading score  \
# District Summary      24649428               78.99                  81.88
#
#                   Passing math score (%)  Passing reading score (%)  \
# District Summary                   74.98                      85.81
#
#                   Passing math & reading score (%)
# District Summary                             65.17

# %%
# School name
school = schools_complete.drop_duplicates(subset=['school_name'])
total_students_school = schools_complete["school_name"].value_counts()

# %%
# School type
school_summary = school[["school_name","type",]]

# %%
# Total students & budget
school_df = schools_complete.groupby(['school_name','type','budget'], sort=False).size().reset_index(name='Total students')

# %%
# Per student budget
school_df['Per student budget'] = school_df['budget'] / school_df['Total students']

# %%
# Average math score
avg_math_df = schools_complete.groupby('school_name', sort=False)['math_score'].mean().reset_index(name='Average math score')
avg_math = avg_math_df['Average math score']
school_df.insert(5, 'Average math score per school', avg_math)

# %%
# Average reading score
avg_reading_df = schools_complete.groupby('school_name', sort=False)['reading_score'].mean().reset_index(name='Average reading score')
avg_reading = avg_reading_df['Average reading score']
school_df.insert(6, 'Average reading score per school', avg_reading)

# %%
# % passing math (the percentage of students who passed math)
math_pass_df = final_maths.groupby('school_name', sort=False)['math_score'].count().reset_index(name='Math students passed')
math_pass = math_pass_df['Math students passed']
school_df.insert(7, 'Math students passed', math_pass)

school_df['Passing math per school (%)'] = round(school_df['Math students passed'] / school_df['Total students'] * 100, 2)
school_df = school_df.drop(columns=['Math students passed'])

# %%
# % passing reading (the percentage of students who passed reading
reading_pass_df = final_reading.groupby('school_name', sort=False)['reading_score'].count().reset_index(name='Reading students passed')
reading_pass = reading_pass_df['Reading students passed']
school_df.insert(8, 'Reading students passed', reading_pass)

school_df['Passing reading per school (%)'] = round(school_df['Reading students passed'] / school_df['Total students'] * 100, 2)
school_df = school_df.drop(columns=['Reading students passed'])

# %%
# % overall passing (the percentage of students who passed math AND reading)
total_pass_df = pass_overall.groupby('school_name', sort=False)['reading_score'].count().reset_index(name='Combined students passed')
total_pass = total_pass_df['Combined students passed']
school_df.insert(9, 'Combined students passed', total_pass)

school_df['Passing math and reading score (%)'] = round(school_df['Combined students passed'] / school_df['Total students'] * 100, 2)
school_df = school_df.drop(columns=['Combined students passed'])

# %%
# Final cosmetic changes
school_df = school_df.rename(columns={"school_name":"School name","type":"School type", "budget":"School budget"})
school_df
# Out:
#               School name School type  School budget  Total students  \
# 0       Huang High School    District        1910635            2917
# 1    Figueroa High School    District        1884411            2949
# 2     Shelton High School     Charter        1056600            1761
# 3   Hernandez High School    District        3022020            4635
# 4     Griffin High School     Charter         917500            1468
# 5      Wilson High School     Charter        1319574            2283
# 6     Cabrera High School     Charter        1081356            1858
# 7      Bailey High School    District        3124928            4976
# 8      Holden High School     Charter         248087             427
# 9        Pena High School     Charter         585858             962
# 10     Wright High School     Charter        1049400            1800
# 11  Rodriguez High School    District        2547363            3999
# 12    Johnson High School    District        3094650            4761
# 13       Ford High School    District        1763916            2739
# 14     Thomas High School     Charter        1043130            1635
#
#     Per student budget  Average math score per school  \
# 0                655.0                      76.629414
# 1                639.0                      76.711767
# 2                600.0                      83.359455
# 3                652.0                      77.289752
# 4                625.0                      83.351499
# 5                578.0                      83.274201
# 6                582.0                      83.061895
# 7                628.0                      77.048432
# 8                581.0                      83.803279
# 9                609.0                      83.839917
# 10               583.0                      83.682222
# 11               637.0                      76.842711
# 12               650.0                      77.072464
# 13               644.0                      77.102592
# 14               638.0                      83.418349
#
#     Average reading score per school  Passing math per school (%)  \
# 0                          81.182722                        65.68
# 1                          81.158020                        65.99
# 2                          83.725724                        93.87
# 3                          80.934412                        66.75
# 4                          83.816757                        93.39
# 5                          83.989488                        93.87
# 6                          83.975780                        94.13
# 7                          81.033963                        66.68
# 8                          83.814988                        92.51
# 9                          84.044699                        94.59
# 10                         83.955000                        93.33
# 11                         80.744686                        66.37
# 12                         80.966394                        66.06
# 13                         80.746258                        68.31
# 14                         83.848930                        93.27
#
#     Passing reading per school (%)  Passing math and reading score (%)
# 0                            81.32                               53.51
# 1                            80.74                               53.20
# 2                            95.85                               89.89
# 3                            80.86                               53.53
# 4                            97.14                               90.60
# 5                            96.54                               90.58
# 6                            97.04                               91.33
# 7                            81.93                               54.64
# 8                            96.25                               89.23
# 9                            95.95                               90.54
# 10                           96.61                               90.33
# 11                           80.22                               52.99
# 12                           81.22                               53.54
# 13                           79.30                               54.29
# 14                           97.31                               90.95

# %%
#Highest-Performing Schools (by % Overall Passing)
high_perform = school_df.sort_values(by="Passing math and reading score (%)", ascending=False)
high_perform.head(5)
# Out:
#             School name School type  School budget  Total students  \
# 6   Cabrera High School     Charter        1081356            1858
# 14   Thomas High School     Charter        1043130            1635
# 4   Griffin High School     Charter         917500            1468
# 5    Wilson High School     Charter        1319574            2283
# 9      Pena High School     Charter         585858             962
#
#     Per student budget  Average math score per school  \
# 6                582.0                      83.061895
# 14               638.0                      83.418349
# 4                625.0                      83.351499
# 5                578.0                      83.274201
# 9                609.0                      83.839917
#
#     Average reading score per school  Passing math per school (%)  \
# 6                          83.975780                        94.13
# 14                         83.848930                        93.27
# 4                          83.816757                        93.39
# 5                          83.989488                        93.87
# 9                          84.044699                        94.59
#
#     Passing reading per school (%)  Passing math and reading score (%)
# 6                            97.04                               91.33
# 14                           97.31                               90.95
# 4                            97.14                               90.60
# 5                            96.54                               90.58
# 9                            95.95                               90.54

# %%
# Lowest-Performing Schools (by % Overall Passing)
lowest_perform = school_df.sort_values(by="Passing math and reading score (%)", ascending=True)
lowest_perform.iloc[:-10 , :]
# Out:
#               School name School type  School budget  Total students  \
# 11  Rodriguez High School    District        2547363            3999
# 1    Figueroa High School    District        1884411            2949
# 0       Huang High School    District        1910635            2917
# 3   Hernandez High School    District        3022020            4635
# 12    Johnson High School    District        3094650            4761
#
#     Per student budget  Average math score per school  \
# 11               637.0                      76.842711
# 1                639.0                      76.711767
# 0                655.0                      76.629414
# 3                652.0                      77.289752
# 12               650.0                      77.072464
#
#     Average reading score per school  Passing math per school (%)  \
# 11                         80.744686                        66.37
# 1                          81.158020                        65.99
# 0                          81.182722                        65.68
# 3                          80.934412                        66.75
# 12                         80.966394                        66.06
#
#     Passing reading per school (%)  Passing math and reading score (%)
# 11                           80.22                               52.99
# 1                            80.74                               53.20
# 0                            81.32                               53.51
# 3                            80.86                               53.53
# 12                           81.22                               53.54

# %%
# Math Scores by Grade
m_scores_df = schools_complete.groupby(['school_name','grade'], sort=False)['math_score'].mean().reset_index(name='math_avg')
m_scores_sorted_df = m_scores_df.sort_values(["school_name"], ascending=True)

m_scores_df = m_scores_sorted_df.rename(columns={"school_name":"School name","grade":"Grade", "math_avg":"Math average score per grade"})
m_scores_df
# Out:
#               School name Grade  Math average score per grade
# 29     Bailey High School  12th                     76.492218
# 28     Bailey High School   9th                     77.083676
# 30     Bailey High School  11th                     77.515588
# 31     Bailey High School  10th                     76.996772
# 25    Cabrera High School   9th                     83.094697
# 24    Cabrera High School  11th                     82.765560
# 26    Cabrera High School  12th                     83.277487
# 27    Cabrera High School  10th                     83.154506
# 4    Figueroa High School  10th                     76.539974
# 6    Figueroa High School   9th                     76.403037
# 5    Figueroa High School  12th                     77.151369
# 7    Figueroa High School  11th                     76.884344
# 52       Ford High School   9th                     77.361345
# 55       Ford High School  10th                     77.672316
# 54       Ford High School  12th                     76.179963
# 53       Ford High School  11th                     76.918058
# 19    Griffin High School  12th                     83.356164
# 18    Griffin High School   9th                     82.044010
# 17    Griffin High School  10th                     84.229064
# 16    Griffin High School  11th                     83.842105
# 15  Hernandez High School  11th                     77.136029
# 14  Hernandez High School   9th                     77.438495
# 12  Hernandez High School  10th                     77.337408
# 13  Hernandez High School  12th                     77.186567
# 32     Holden High School  11th                     85.000000
# 33     Holden High School   9th                     83.787402
# 34     Holden High School  10th                     83.429825
# 35     Holden High School  12th                     82.855422
# 0       Huang High School   9th                     77.027251
# 1       Huang High School  12th                     77.225641
# 3       Huang High School  10th                     75.908735
# 2       Huang High School  11th                     76.446602
# 49    Johnson High School   9th                     77.187857
# 50    Johnson High School  11th                     77.491653
# 51    Johnson High School  10th                     76.691117
# 48    Johnson High School  12th                     76.863248
# 38       Pena High School  11th                     84.328125
# 39       Pena High School  12th                     84.121547
# 36       Pena High School   9th                     83.625455
# 37       Pena High School  10th                     83.372000
# 45  Rodriguez High School  10th                     76.612500
# 46  Rodriguez High School  12th                     77.690748
# 47  Rodriguez High School   9th                     76.859966
# 44  Rodriguez High School  11th                     76.395626
# 9     Shelton High School  10th                     82.917411
# 10    Shelton High School  11th                     83.383495
# 11    Shelton High School   9th                     83.420755
# 8     Shelton High School  12th                     83.778976
# 56     Thomas High School  10th                     83.087886
# 57     Thomas High School  11th                     83.498795
# 58     Thomas High School   9th                     83.590022
# 59     Thomas High School  12th                     83.497041
# 20     Wilson High School  10th                     83.724422
# 21     Wilson High School  11th                     83.195326
# 22     Wilson High School   9th                     83.085578
# 23     Wilson High School  12th                     83.035794
# 43     Wright High School  12th                     83.644986
# 42     Wright High School   9th                     83.264706
# 41     Wright High School  11th                     83.836782
# 40     Wright High School  10th                     84.010288

# %%
# Reading Scores by Grade
read_scores_df = schools_complete.groupby(['school_name','grade'], sort=False)['reading_score'].mean().reset_index(name='read_avg')
read_scores_sorted_df = read_scores_df.sort_values(["school_name"], ascending=True)

read_scores_df = read_scores_sorted_df.rename(columns={"school_name":"School name","grade":"Grade", "read_avg":"Reading average score per grade"})
read_scores_df
# Out:
#               School name Grade  Reading average score per grade
# 29     Bailey High School  12th                        80.912451
# 28     Bailey High School   9th                        81.303155
# 30     Bailey High School  11th                        80.945643
# 31     Bailey High School  10th                        80.907183
# 25    Cabrera High School   9th                        83.676136
# 24    Cabrera High School  11th                        83.788382
# 26    Cabrera High School  12th                        84.287958
# 27    Cabrera High School  10th                        84.253219
# 4    Figueroa High School  10th                        81.408912
# 6    Figueroa High School   9th                        81.198598
# 5    Figueroa High School  12th                        81.384863
# 7    Figueroa High School  11th                        80.640339
# 52       Ford High School   9th                        80.632653
# 55       Ford High School  10th                        81.262712
# 54       Ford High School  12th                        80.662338
# 53       Ford High School  11th                        80.403642
# 19    Griffin High School  12th                        84.013699
# 18    Griffin High School   9th                        83.369193
# 17    Griffin High School  10th                        83.706897
# 16    Griffin High School  11th                        84.288089
# 15  Hernandez High School  11th                        81.396140
# 14  Hernandez High School   9th                        80.866860
# 12  Hernandez High School  10th                        80.660147
# 13  Hernandez High School  12th                        80.857143
# 32     Holden High School  11th                        83.815534
# 33     Holden High School   9th                        83.677165
# 34     Holden High School  10th                        83.324561
# 35     Holden High School  12th                        84.698795
# 0       Huang High School   9th                        81.290284
# 1       Huang High School  12th                        80.305983
# 3       Huang High School  10th                        81.512386
# 2       Huang High School  11th                        81.417476
# 49    Johnson High School   9th                        81.260714
# 50    Johnson High School  11th                        80.616027
# 51    Johnson High School  10th                        80.773431
# 48    Johnson High School  12th                        81.227564
# 38       Pena High School  11th                        84.335938
# 39       Pena High School  12th                        84.591160
# 36       Pena High School   9th                        83.807273
# 37       Pena High School  10th                        83.612000
# 45  Rodriguez High School  10th                        80.629808
# 46  Rodriguez High School  12th                        80.376426
# 47  Rodriguez High School   9th                        80.993127
# 44  Rodriguez High School  11th                        80.864811
# 9     Shelton High School  10th                        83.441964
# 10    Shelton High School  11th                        84.373786
# 11    Shelton High School   9th                        84.122642
# 8     Shelton High School  12th                        82.781671
# 56     Thomas High School  10th                        84.254157
# 57     Thomas High School  11th                        83.585542
# 58     Thomas High School   9th                        83.728850
# 59     Thomas High School  12th                        83.831361
# 20     Wilson High School  10th                        84.021452
# 21     Wilson High School  11th                        83.764608
# 22     Wilson High School   9th                        83.939778
# 23     Wilson High School  12th                        84.317673
# 43     Wright High School  12th                        84.073171
# 42     Wright High School   9th                        83.833333
# 41     Wright High School  11th                        84.156322
# 40     Wright High School  10th                        83.812757

# %%
# Scores by School Spending
school_spending_df = school_df.drop(columns=['School type', 'School budget', 'Total students'])
school_spending_df['Cutoff groups'] = pd.qcut(school_spending_df['Per student budget'],[0, 0.25, 0.5, 0.75, 1])
school_spending_df
# Out:
#               School name  Per student budget  Average math score per school  \
# 0       Huang High School               655.0                      76.629414
# 1    Figueroa High School               639.0                      76.711767
# 2     Shelton High School               600.0                      83.359455
# 3   Hernandez High School               652.0                      77.289752
# 4     Griffin High School               625.0                      83.351499
# 5      Wilson High School               578.0                      83.274201
# 6     Cabrera High School               582.0                      83.061895
# 7      Bailey High School               628.0                      77.048432
# 8      Holden High School               581.0                      83.803279
# 9        Pena High School               609.0                      83.839917
# 10     Wright High School               583.0                      83.682222
# 11  Rodriguez High School               637.0                      76.842711
# 12    Johnson High School               650.0                      77.072464
# 13       Ford High School               644.0                      77.102592
# 14     Thomas High School               638.0                      83.418349
#
#     Average reading score per school  Passing math per school (%)  \
# 0                          81.182722                        65.68
# 1                          81.158020                        65.99
# 2                          83.725724                        93.87
# 3                          80.934412                        66.75
# 4                          83.816757                        93.39
# 5                          83.989488                        93.87
# 6                          83.975780                        94.13
# 7                          81.033963                        66.68
# 8                          83.814988                        92.51
# 9                          84.044699                        94.59
# 10                         83.955000                        93.33
# 11                         80.744686                        66.37
# 12                         80.966394                        66.06
# 13                         80.746258                        68.31
# 14                         83.848930                        93.27
#
#     Passing reading per school (%)  Passing math and reading score (%)  \
# 0                            81.32                               53.51
# 1                            80.74                               53.20
# 2                            95.85                               89.89
# 3                            80.86                               53.53
# 4                            97.14                               90.60
# 5                            96.54                               90.58
# 6                            97.04                               91.33
# 7                            81.93                               54.64
# 8                            96.25                               89.23
# 9                            95.95                               90.54
# 10                           96.61                               90.33
# 11                           80.22                               52.99
# 12                           81.22                               53.54
# 13                           79.30                               54.29
# 14                           97.31                               90.95
#
#        Cutoff groups
# 0     (641.5, 655.0]
# 1     (628.0, 641.5]
# 2     (591.5, 628.0]
# 3     (641.5, 655.0]
# 4     (591.5, 628.0]
# 5   (577.999, 591.5]
# 6   (577.999, 591.5]
# 7     (591.5, 628.0]
# 8   (577.999, 591.5]
# 9     (591.5, 628.0]
# 10  (577.999, 591.5]
# 11    (628.0, 641.5]
# 12    (641.5, 655.0]
# 13    (641.5, 655.0]
# 14    (628.0, 641.5]

# %%
# Scores by School Size
scores_by_size = school_df.loc[:, ['School name','Total students','Passing math and reading score (%)']]
scores_by_size[ 'School size'] = pd.qcut(scores_by_size['Total students'],[0, 0.33, 0.66, 1], labels=['Small', 'Medium', 'Large'])
scores_by_size
# Out:
#               School name  Total students  Passing math and reading score (%)  \
# 0       Huang High School            2917                               53.51
# 1    Figueroa High School            2949                               53.20
# 2     Shelton High School            1761                               89.89
# 3   Hernandez High School            4635                               53.53
# 4     Griffin High School            1468                               90.60
# 5      Wilson High School            2283                               90.58
# 6     Cabrera High School            1858                               91.33
# 7      Bailey High School            4976                               54.64
# 8      Holden High School             427                               89.23
# 9        Pena High School             962                               90.54
# 10     Wright High School            1800                               90.33
# 11  Rodriguez High School            3999                               52.99
# 12    Johnson High School            4761                               53.54
# 13       Ford High School            2739                               54.29
# 14     Thomas High School            1635                               90.95
#
#    School size
# 0       Medium
# 1        Large
# 2        Small
# 3        Large
# 4        Small
# 5       Medium
# 6       Medium
# 7        Large
# 8        Small
# 9        Small
# 10      Medium
# 11       Large
# 12       Large
# 13      Medium
# 14       Small

# %%
# Scores by School Type
scores_by_type = school_df.loc[:, ['School name','School type','Passing math and reading score (%)']]
scores_by_type
# Out:
#               School name School type  Passing math and reading score (%)
# 0       Huang High School    District                               53.51
# 1    Figueroa High School    District                               53.20
# 2     Shelton High School     Charter                               89.89
# 3   Hernandez High School    District                               53.53
# 4     Griffin High School     Charter                               90.60
# 5      Wilson High School     Charter                               90.58
# 6     Cabrera High School     Charter                               91.33
# 7      Bailey High School    District                               54.64
# 8      Holden High School     Charter                               89.23
# 9        Pena High School     Charter                               90.54
# 10     Wright High School     Charter                               90.33
# 11  Rodriguez High School    District                               52.99
# 12    Johnson High School    District                               53.54
# 13       Ford High School    District                               54.29
# 14     Thomas High School     Charter                               90.95
